# %% [markdown]
# d-sandbox
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 400px">
# </div>

# %% [markdown]
# # Spark SQL
# 1. Run a SQL query
# 1. Create a DataFrame
# 1. Write same query using DataFrame transformations
# 1. Trigger computation with DataFrame actions
# 1. Convert between DataFrames and SQL
#
# ##### Methods
# - SparkSession (<a href="https://spark.apache.org/docs/latest/api/python/pyspark.sql.html?highlight=sparksession#pyspark.sql.SparkSession" target="_blank">Python</a>/<a href="http://spark.apache.org/docs/latest/api/scala/org/apache/spark/sql/SparkSession.html" target="_blank">Scala</a>): `sql`, `table`
# - DataFrame (<a href="https://spark.apache.org/docs/latest/api/python/pyspark.sql.html?highlight=dataframe#pyspark.sql.DataFrame" target="_blank">Python</a>/<a href="http://spark.apache.org/docs/latest/api/scala/org/apache/spark/sql/Dataset.html" target="_blank">Scala</a>):
#   - Transformations:  `select`, `where`, `orderBy`
#   - Actions: `show`, `count`, `take`
#   - Other methods: `printSchema`, `schema`, `createOrReplaceTempView`

# %%
# %run ./Includes/Classroom-Setup-SQL
# Out:
# Datasets mounted and student environment set up

# %% [markdown]
# ### ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Run a SQL query
# Use `SparkSession` to run SQL

# %%
budgetDF = spark.sql("""
SELECT name, price
FROM products
WHERE price < 200
ORDER BY price
""")

# %% [markdown]
# View results in the returned DataFrame

# %%
budgetDF.show()
# Out:
# +--------------------+-----+
# |                name|price|
# +--------------------+-----+
# |Standard Foam Pillow| 59.0|
# |    King Foam Pillow| 79.0|
# |Standard Down Pillow|119.0|
# |    King Down Pillow|159.0|
# +--------------------+-----+

# %%
display(budgetDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>price</th></tr></thead><tbody><tr><td>Standard Foam Pillow</td><td>59.0</td></tr><tr><td>King Foam Pillow</td><td>79.0</td></tr><tr><td>Standard Down Pillow</td><td>119.0</td></tr><tr><td>King Down Pillow</td><td>159.0</td></tr></tbody></table></div>

# %% [markdown]
# ### ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Create a DataFrame
# Use `SparkSession` to create a DataFrame from a table

# %%
productsDF = spark.table("products")
display(productsDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>item_id</th><th>name</th><th>price</th></tr></thead><tbody><tr><td>M_PREM_Q</td><td>Premium Queen Mattress</td><td>1795.0</td></tr><tr><td>M_STAN_F</td><td>Standard Full Mattress</td><td>945.0</td></tr><tr><td>M_PREM_F</td><td>Premium Full Mattress</td><td>1695.0</td></tr><tr><td>M_PREM_T</td><td>Premium Twin Mattress</td><td>1095.0</td></tr><tr><td>M_PREM_K</td><td>Premium King Mattress</td><td>1995.0</td></tr><tr><td>P_DOWN_S</td><td>Standard Down Pillow</td><td>119.0</td></tr><tr><td>M_STAN_Q</td><td>Standard Queen Mattress</td><td>1045.0</td></tr><tr><td>M_STAN_K</td><td>Standard King Mattress</td><td>1195.0</td></tr><tr><td>M_STAN_T</td><td>Standard Twin Mattress</td><td>595.0</td></tr><tr><td>P_FOAM_S</td><td>Standard Foam Pillow</td><td>59.0</td></tr><tr><td>P_FOAM_K</td><td>King Foam Pillow</td><td>79.0</td></tr><tr><td>P_DOWN_K</td><td>King Down Pillow</td><td>159.0</td></tr></tbody></table></div>

# %% [markdown]
# Access schema of DataFrame

# %%
productsDF.printSchema()
# Out:
# root
#  |-- item_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- price: double (nullable = true)

# %%
productsDF.schema
# Out:
# Out[99]: StructType(List(StructField(item_id,StringType,true),StructField(name,StringType,true),StructField(price,DoubleType,true)))

# %% [markdown]
# ### ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Write same query with DataFrame transformations

# %%
budgetDF = (productsDF
  .select("name", "price")
  .where("price < 200")
  .orderBy("price")
)

# %% [markdown]
# ### ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Trigger computation with DataFrame actions

# %%
budgetDF.count()
# Out:
# Out[101]: 4

# %%
budgetDF.take(2)
# Out:
# Out[102]: [Row(name='Standard Foam Pillow', price=59.0),
#  Row(name='King Foam Pillow', price=79.0)]

# %% [markdown]
# ### ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Convert between DataFrames and SQL

# %%
budgetDF.createOrReplaceTempView("budget")

# %%
display(spark.sql("SELECT * FROM budget"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>price</th></tr></thead><tbody><tr><td>Standard Foam Pillow</td><td>59.0</td></tr><tr><td>King Foam Pillow</td><td>79.0</td></tr><tr><td>Standard Down Pillow</td><td>119.0</td></tr><tr><td>King Down Pillow</td><td>159.0</td></tr></tbody></table></div>

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Lab
#
# 1. Create a DataFrame from the `Event` table
# 1. Display DataFrame and inspect schema
# 1. Apply transformations to filter and sort `macOS` events
# 1. Count results and take first 5 rows
# 1. Create the same DataFrame using SQL query
#
# ##### Methods
# - <a href="http://spark.apache.org/docs/latest/api/scala/org/apache/spark/sql/SparkSession.html" target="_blank">SparkSession</a>: `sql`, `table`
# - <a href="http://spark.apache.org/docs/latest/api/scala/org/apache/spark/sql/Dataset.html" target="_blank">DataFrame</a> transformations: `select`, `where`, `orderBy`
# - <a href="http://spark.apache.org/docs/latest/api/scala/org/apache/spark/sql/Dataset.html" target="_blank">DataFrame</a> actions: `select`, `count`, `take`
# - Other <a href="http://spark.apache.org/docs/latest/api/scala/org/apache/spark/sql/Dataset.html" target="_blank">DataFrame</a> methods: `printSchema`, `schema`, `createOrReplaceTempView`

# %% [markdown]
# ### 1. Create a DataFrame from the `events` table
# - Use SparkSession to create a DataFrame from the `events` table

# %%
# TODO
eventDF = spark.sql("""
SELECT event_name, device, items, event_timestamp
FROM events
""")

# %% [markdown]
# ### 2. Display DataFrame and inspect schema
# - Use methods above to inspect DataFrame contents and schema

# %%
# TODO
display(eventDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>event_name</th><th>device</th><th>items</th><th>event_timestamp</th></tr></thead><tbody><tr><td>warranty</td><td>macOS</td><td>List()</td><td>1593878946592107</td></tr><tr><td>press</td><td>Windows</td><td>List()</td><td>1593877011756535</td></tr><tr><td>add_item</td><td>macOS</td><td>List(List(null, M_STAN_T, Standard Twin Mattress, 595.0, 595.0, 1))</td><td>1593878815459100</td></tr><tr><td>mattresses</td><td>iOS</td><td>List()</td><td>1593878809276923</td></tr><tr><td>mattresses</td><td>Windows</td><td>List()</td><td>1593878628143633</td></tr><tr><td>main</td><td>Windows</td><td>List()</td><td>1593878634344194</td></tr><tr><td>main</td><td>iOS</td><td>List()</td><td>1593877936171803</td></tr><tr><td>main</td><td>macOS</td><td>List()</td><td>1593876843215329</td></tr><tr><td>warranty</td><td>Android</td><td>List()</td><td>1593879213196400</td></tr><tr><td>main</td><td>Windows</td><td>List()</td><td>1593876713246514</td></tr><tr><td>original</td><td>iOS</td><td>List()</td><td>1593878170903989</td></tr><tr><td>main</td><td>Linux</td><td>List()</td><td>1593878036347579</td></tr><tr><td>down</td><td>Android</td><td>List()</td><td>1593879125815755</td></tr><tr><td>main</td><td>Linux</td><td>List()</td><td>1593878672173087</td></tr><tr><td>main</td><td>macOS</td><td>List()</td><td>1593876429415452</td></tr><tr><td>mattresses</td><td>iOS</td><td>List()</td><td>1593876687337581</td></tr><tr><td>premium</td><td>macOS</td><td>List()</td><td>1593877973962436</td></tr><tr><td>reviews</td><td>Windows</td><td>List()</td><td>1593876944661570</td></tr><tr><td>original</td><td>iOS</td><td>List()</td><td>1593877788141768</td></tr><tr><td>main</td><td>iOS</td><td>List()</td><td>1593877497207417</td></tr><tr><td>main</td><td>Android</td><td>List()</td><td>1593877271099453</td></tr><tr><td>reviews</td><td>iOS</td><td>List()</td><td>1593878356880855</td></tr><tr><td>main</td><td>Android</td><td>List()</td><td>1593879239050626</td></tr><tr><td>mattresses</td><td>Windows</td><td>List()</td><td>1593877608354608</td></tr><tr><td>cart</td><td>Android</td><td>List(List(null, M_STAN_F, Standard Full Mattress, 945.0, 945.0, 1))</td><td>1593878899159806</td></tr><tr><td>cart</td><td>Windows</td><td>List(List(null, M_PREM_T, Premium Twin Mattress, 1095.0, 1095.0, 1))</td><td>1593879003979444</td></tr><tr><td>main</td><td>macOS</td><td>List()</td><td>1593879039209043</td></tr><tr><td>main</td><td>iOS</td><td>List()</td><td>1593876687186216</td></tr><tr><td>faq</td><td>macOS</td><td>List()</td><td>1593878984168461</td></tr><tr><td>mattresses</td><td>macOS</td><td>List()</td><td>1593877076686136</td></tr><tr><td>main</td><td>iOS</td><td>List()</td><td>1593876831949693</td></tr><tr><td>pillows</td><td>Windows</td><td>List()</td><td>1593879086932085</td></tr><tr><td>main</td><td>macOS</td><td>List()</td><td>1593878642524459</td></tr><tr><td>main</td><td>Linux</td><td>List()</td><td>1593877977050669</td></tr><tr><td>pillows</td><td>Windows</td><td>List()</td><td>1593877512951677</td></tr><tr><td>mattresses</td><td>Windows</td><td>List()</td><td>1593878914256162</td></tr><tr><td>warranty</td><td>Android</td><td>List()</td><td>1593878620744974</td></tr><tr><td>pillows</td><td>Windows</td><td>List()</td><td>1593878751138630</td></tr><tr><td>foam</td><td>iOS</td><td>List()</td><td>1593878206468778</td></tr><tr><td>main</td><td>Windows</td><td>List()</td><td>1593878429326706</td></tr><tr><td>checkout</td><td>Android</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td><td>1593879230950221</td></tr><tr><td>mattresses</td><td>Android</td><td>List()</td><td>1593876443386829</td></tr><tr><td>warranty</td><td>Chrome OS</td><td>List()</td><td>1593878823421232</td></tr><tr><td>main</td><td>Windows</td><td>List()</td><td>1593877041350735</td></tr><tr><td>mattresses</td><td>Android</td><td>List()</td><td>1593879240812006</td></tr> ...

# %%
# TODO
eventDF.printSchema()
# Out:
# root
#  |-- event_name: string (nullable = true)
#  |-- device: string (nullable = true)
#  |-- items: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- coupon: string (nullable = true)
#  |    |    |-- item_id: string (nullable = true)
#  |    |    |-- item_name: string (nullable = true)
#  |    |    |-- item_revenue_in_usd: double (nullable = true)
#  |    |    |-- price_in_usd: double (nullable = true)
#  |    |    |-- quantity: long (nullable = true)
#  |-- event_timestamp: long (nullable = true)

# %% [markdown]
# -sandbox
# ### 3. Apply transformations to filter and sort `macOS` events
# - Filter for rows where `device` is `macOS`
# - Sort rows by `event_timestamp`
#
# <img alt="Hint" title="Hint" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-light-bulb.svg"/>&nbsp;**Hint:** Use single and double quotes in your filter SQL expression

# %%
# TODO
macDF =(eventDF
        .select("event_name", "device", "items", "event_timestamp")
        .where("'device' == 'macOS'")
        .orderBy("event_timestamp")
)

# %% [markdown]
# ### 4. Count results and take first 5 rows
# - Use DataFrame actions to count and take rows

# %%
# TODO
numRows = macDF.count()
rows = macDF.take(5)

# %%
numRows
# Out:
# Out[110]: 0

# %%
rows
# Out:
# Out[111]: []

# %% [markdown]
# -sandbox
# ##### <img alt="Best Practice" title="Best Practice" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-blue-ribbon.svg"/> Check your work

# %%
from pyspark.sql import Row

assert(numRows == 1938215)
assert(len(rows) == 5)
assert(type(rows[0]) == Row)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <command-2861581124099582> in <module>
#       1 from pyspark.sql import Row
#       2
# ----> 3 assert(numRows == 1938215)
#       4 assert(len(rows) == 5)
#       5 assert(type(rows[0]) == Row)
#
# AssertionError:

# %% [markdown]
# ### 5. Create the same DataFrame using SQL query
# - Use SparkSession to run a sql query on the `events` table
# - Use SQL commands above to write the same filter and sort query used earlier

# %%
# TODO
macSQLDF = spark.sql("""
SELECT event_name, device, items, event_timestamp
FROM events WHERE device=='macOS'
ORDER BY event_timestamp ASC
""")

display(macSQLDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>event_name</th><th>device</th><th>items</th><th>event_timestamp</th></tr></thead><tbody><tr><td>mattresses</td><td>macOS</td><td>List()</td><td>1592539216262230</td></tr><tr><td>mattresses</td><td>macOS</td><td>List()</td><td>1592539218667144</td></tr><tr><td>reviews</td><td>macOS</td><td>List()</td><td>1592539218939615</td></tr><tr><td>guest</td><td>macOS</td><td>List(List(null, M_STAN_F, Standard Full Mattress, 945.0, 945.0, 1))</td><td>1592539225913937</td></tr><tr><td>main</td><td>macOS</td><td>List()</td><td>1592539226602157</td></tr><tr><td>original</td><td>macOS</td><td>List()</td><td>1592539229480664</td></tr><tr><td>main</td><td>macOS</td><td>List()</td><td>1592539231022266</td></tr><tr><td>guest</td><td>macOS</td><td>List(List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1), List(null, P_FOAM_K, King Foam Pillow, 79.0, 79.0, 1))</td><td>1592539231776200</td></tr><tr><td>delivery</td><td>macOS</td><td>List()</td><td>1592539232284730</td></tr><tr><td>main</td><td>macOS</td><td>List()</td><td>1592539233151229</td></tr><tr><td>shipping_info</td><td>macOS</td><td>List(List(null, M_STAN_F, Standard Full Mattress, 945.0, 945.0, 1))</td><td>1592539235059340</td></tr><tr><td>mattresses</td><td>macOS</td><td>List()</td><td>1592539236295422</td></tr><tr><td>add_item</td><td>macOS</td><td>List(List(null, M_STAN_Q, Standard Queen Mattress, 1045.0, 1045.0, 1))</td><td>1592539237432046</td></tr><tr><td>main</td><td>macOS</td><td>List()</td><td>1592539289834596</td></tr><tr><td>add_item</td><td>macOS</td><td>List(List(NEWBED10, P_FOAM_K, King Foam Pillow, 71.10000000000001, 79.0, 1))</td><td>1592539295857466</td></tr><tr><td>main</td><td>macOS</td><td>List()</td><td>1592539299325832</td></tr><tr><td>main</td><td>macOS</td><td>List()</td><td>1592539302562339</td></tr><tr><td>mattresses</td><td>macOS</td><td>List()</td><td>1592539305168803</td></tr><tr><td>guest</td><td>macOS</td><td>List(List(NEWBED10, M_STAN_K, Standard King Mattress, 1075.5, 1195.0, 1))</td><td>1592539309500570</td></tr><tr><td>add_item</td><td>macOS</td><td>List(List(NEWBED10, M_STAN_T, Standard Twin Mattress, 535.5, 595.0, 1))</td><td>1592539310482088</td></tr><tr><td>register</td><td>macOS</td><td>List(List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1))</td><td>1592539331750583</td></tr><tr><td>shipping_info</td><td>macOS</td><td>List(List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1))</td><td>1592539339785249</td></tr><tr><td>mattresses</td><td>macOS</td><td>List()</td><td>1592539343571171</td></tr><tr><td>register</td><td>macOS</td><td>List(List(null, M_STAN_K, Standard King Mattress, 1195.0, 1195.0, 1))</td><td>1592539346041388</td></tr><tr><td>pillows</td><td>macOS</td><td>List()</td><td>1592539347745795</td></tr><tr><td>original</td><td>macOS</td><td>List()</td><td>1592539367676338</td></tr><tr><td>press</td><td>macOS</td><td>List()</td><td>1592539383618319</td></tr><tr><td>cart</td><td>macOS</td><td>List(List(NEWBED10, M_PREM_Q, Premium Queen Mattress, 1615.5, 1795.0, 1))</td><td>1592539387295729</td></tr><tr><td>main</td><td>macOS</td><td>List()</td><td>1592539388476666</td></tr><tr><td>original</td><td>macOS</td><td>List()</td><td>1592539388713269</td></tr><tr><td>add_item</td><td>macOS</td><td>List(List(null, M_STAN_F, Standard Full Mattress, 945.0, 945.0, 1))</td><td>1592539389057282</td></tr><tr><td>mattresses</td><td>macOS</td><td>List()</td><td>1592539394685322</td></tr><tr><td>main</td><td>macOS</td><td>List()</td><td>1592539400000826</td></tr><tr><td>shipping_info</td><td>macOS</td><td>List(List(NEWBED10, M_STAN_Q, Standard Queen Mattress, 940.5, 1045.0, 1))</td><td>1592539402672930</td></tr><tr><td>original</td><td>macOS</td><td>List()</td><td>1592539414743914</td></tr><tr><td>main</td><td>macOS</td><td>List()</td><td>1592539417279950</td></tr><tr><td>mattresses</td><td>macOS</td><td> ...

# %%
macSQLDF.take(5)
# Out:
# Out[120]: [Row(event_name='mattresses', device='macOS', items=[], event_timestamp=1592539216262230),
#  Row(event_name='mattresses', device='macOS', items=[], event_timestamp=1592539218667144),
#  Row(event_name='reviews', device='macOS', items=[], event_timestamp=1592539218939615),
#  Row(event_name='guest', device='macOS', items=[Row(coupon=None, item_id='M_STAN_F', item_name='Standard Full Mattress', item_revenue_in_usd=945.0, price_in_usd=945.0, quantity=1)], event_timestamp=1592539225913937),
#  Row(event_name='main', device='macOS', items=[], event_timestamp=1592539226602157)]

# %% [markdown]
# -sandbox
# %md ##### <img alt="Best Practice" title="Best Practice" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-blue-ribbon.svg"/> Check your work
# - You should only see `macOS` values in the `device` column
# - The fifth row should be an event with timestamp `1592539226602157`

# %% [markdown]
# ### Classroom Cleanup

# %%
# %run ./Includes/Classroom-Cleanup
